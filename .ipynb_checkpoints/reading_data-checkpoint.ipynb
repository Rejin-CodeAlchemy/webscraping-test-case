# %% [markdown]
# ## Overview

# %% [markdown]
# The goal of this Proof of Concept (PoC) project is to create a tool that do web scraping of Website "https://www.holidify.com/country/india/places-to-visit.html".

# %% [markdown]
# ### Key Features:

# %% [markdown]
# - Scrape tourist places info:
#
#   Extract place names, State, description, Rating out of 5.0, Ranking out of 100, number of tourist attractions and best time to visit.
#
# - Store Data: Save the scraped data to a CSV file or database for future analysis.

# %%
#!pip install requests beautifulsoup4 pandas

# %%
#importing Libraries
import os
import numpy as np
import pandas as pd
import requests
import re
from bs4 import BeautifulSoup

# %%
webpage = "https://www.holidify.com/country/india/places-to-visit.html"

response = requests.get(url=webpage)
response.ok
# Out:
# True

# %%
inspect_data = BeautifulSoup(response.text,'html.parser')

# %%
containers = inspect_data.findAll("div",{"class":"col-12 col-md-6 pr-md-3"})
len(containers)
# Out:
# 42

# %%
data_list = []

# %%
containers[0]
# Out:
# <div class="col-12 col-md-6 pr-md-3">
# <div class="card content-card" data-itemid="GULMARG">
# <a data-href="/places/gulmarg/" data-position="1" href="/places/gulmarg/">
# <h3 class="card-heading"> 1. Gulmarg </h3>
# <div class="position-relative">
# <div class="collection-scrollable" data-hotel-position="1">
# <img alt="" class="card-img-top lazy" data-original="https://www.holidify.com/images/bgImages/GULMARG.jpg" src="/res/images/patt.png"/>
# <div class="lazyBG card-img-top" data-original="https://www.holidify.com/images/compressed/dest_wiki_5433.jpg" style="background-image:url('https://holidify.com/images/patt.png');">
# </div>
# <div class="lazyBG card-img-top" data-original="https://www.holidify.com/images/cmsuploads/compressed/IMG_3768_20190710152743.JPG" style="background-image:url('https://holidify.com/images/patt.png');">
# </div>
# <div class="lazyBG card-img-top" data-original="https://www.holidify.com/images/cmsuploads/compressed/2771936432_d603c3fbd9_b_20190710152801.jpg" style="background-image:url('https://holidify.com/images/patt.png');">
# </div>
# <div class="lazyBG card-img-top" data-original="https://www.holidify.com/images/compressed/266.jpg" style="background-image:url('https://holidify.com/images/patt.png');">
# </div>
# <div class="lazyBG card-img-top" data-original="https://www.holidify.com/images/cmsuploads/compressed/D3A_9955_20190710152734.jpg" style="background-image:url('https://holidify.com/images/patt.png');">
# </div>
# </div>
# <span class="rating-badge" style="background-color:#247c2a;">
# <b>4.4</b>
# <span class="light"> /5</span>
# </span>
# </div>
# </a>
# <div class="card-body">
# <p class="objective">
#
# 		      		1 out of 100 <br/> Places to visit in India
#
#
#
# 		        <span class="divider"> </span>
# 		        29 <br/> Tourist attractions
#
# 		    </p>
# <p class="mb-2"> <b>Located in : <a href="/state/jammu-and-kashmir/"> Jammu and Kashmir </a></b></p>
# <p class="mb-3"> <b> Known For : </b>
# <span class="clickable align-middle" onclick=";openLink('https://www.holidify.com/places/gulmarg/gulmarg-gondola-sightseeing-1901.html')"> <b> Gulmarg Gondola </b> </span>
# <span class="clickable" onclick='openLink("https://www.holidify.com/places/gulmarg/gulmarg-gondola-sightseeing-1901.html")'> </span>
# <span class="divider"></span>
# <span class="clickable align-middle" onclick=";openLink('https://www.holidify.com/places/gulmarg/alpather-lake-sightseeing-4983.html')"> <b> Alpather Lake  </b> </span>
# <span class="divider"></span>
# <span class="clickable align-middle" onclick=";openLink('https://www.holidify.com/places/gulmarg/apharwat-peak-sightseeing-120958.html')"> <b> Apharwat Peak  </b> </span>
# </p>
# <p class="card-text"> Situated at an altitude of 2730 m above sea level, Gulmarg is a popular skiing destination located in Pir Panjal Range of Union territory of Jammu and Kashmir. Surrounded by snow-covered lofty Himalayas, meadows of flowers, deep ravines, evergreen forested valleys, Gulmarg also has the world's secon... </p>
# <p class="mb-3"><b>Best Time: </b> October to June </p>
# </div>
# <div class="content-card-footer" data-href="/places/gulmarg/" data-position="1">
# <a class="btn btn-blue" href="/places/gulmarg/packages.html">
# 		      View Packages
# 		    </a>
# <a class="btn btn-read-more" onclick='openLink("/places/gulmarg/")'> Read More </a>
# </div>
# </div>
# </div>

# %%
for container in containers:
    data = {}
    pname = container.find("h3", {"class":"card-heading"} )
    data['p_name'] = pname.get_text().split('.')[1].split('-')[0].strip()

    rating = container.find("span",{"class":"rating-badge"})
    if rating:
        rating_val = rating.find('b').get_text().strip()
        rating_max = rating.find('span',{"class":"light"}).get_text().strip()
        rating = rating_val+rating_max
    else: rating = 0
    data['p_rating'] = rating
    
    objective = container.find("p", {"class":{"objective"}}).get_text().strip()
    data['rank'] = objective.split('Places to visit in India')[0]
    if objective.split('Places to visit in India')[1]:
        data['tourist_attractions'] = objective.split('Places to visit in India')[1].strip().split()[0]
    else: data['tourist_attractions'] =''

    mb = container.find("p", {"class":{"mb-2"}})
    if mb:
        data['location'] = mb.find('a').get_text().strip()
    else:data['location'] =''

    data['description'] = container.find('p',{'class':'card-text'}).get_text().strip()

    mb_3 = container.findAll('p',class_='mb-3')
    for mb in mb_3:
        if mb.find('b').get_text().strip()=='Known For :':
            mb3 = mb.findAll("span",{"class": "clickable align-middle"})
            known_for=[]
            for span in mb3:
                known_for.append(span.find('b').get_text().strip())
            data['known_for'] = known_for
        elif "Best Time:" in mb.get_text():
            data['best_time'] = mb.get_text().split("Best Time: ")[len(mb.get_text().split("Best Time: "))-1]
    data_list.append(data)

# %%
result = pd.DataFrame(data_list,columns = ['p_name','p_rating','rank','tourist_attractions','location','description','known_for','best_time'])

# %%
result.head(-5)
# Out:
#                          p_name p_rating             rank tourist_attractions  \
# 0                       Gulmarg    4.4/5   1 out of 100                    29
# 1                        Munnar    4.2/5   2 out of 100                    54
# 2                       Gangtok    4.6/5   3 out of 100                    34
# 3                        Manali    4.8/5   4 out of 100                    53
# 4                      Srinagar    4.2/5   5 out of 100                    59
# 5                      Shillong    4.2/5   6 out of 100                    33
# 6                          Ooty    4.5/5   7 out of 100                    43
# 7                    Darjeeling    4.8/5   8 out of 100                    31
# 8                        Ladakh    4.7/5   9 out of 100                    70
# 9                     Rishikesh    4.5/5  10 out of 100                    54
# 10                        Coorg    4.2/5  11 out of 100                    37
# 11                   Mcleodganj    4.2/5  12 out of 100                    42
# 12                      Kashmir    4.6/5  13 out of 100                    45
# 13                       Tawang    4.3/5  14 out of 100                    13
# 14                   Kodaikanal    4.0/5  15 out of 100                    35
# 15                     Nainital    4.4/5  16 out of 100                    33
# 16                       Shimla    4.8/5  17 out of 100                    65
# 17                    Mussoorie    4.8/5  18 out of 100                    36
# 18                     Khajjiar    4.6/5  19 out of 100                    14
# 19                      Wayanad    4.3/5  20 out of 100                    46
# 20                         Agra    4.9/5  21 out of 100                    20
# 21  Andaman and Nicobar Islands    4.6/5  22 out of 100                    81
# 22                     Alleppey    4.8/5  23 out of 100                    39
# 23                          Goa    4.9/5  24 out of 100                   198
# 24                     Amritsar    4.7/5  25 out of 100                    34
# 25                       Jaipur    4.8/5  26 out of 100                    77
# 26                      Udaipur    4.6/5  27 out of 100                    43
# 27                        Delhi    4.7/5  28 out of 100                   121
# 28              Char Dham Yatra    4.7/5  29 out of 100
# 29                     Varanasi    4.8/5  30 out of 100                    43
# 30                       Mumbai    4.7/5  31 out of 100                   120
# 31                    Jaisalmer    4.4/5  32 out of 100                    39
# 32                  Lakshadweep    4.0/5  33 out of 100                    18
# 33                      Jodhpur    4.3/5  34 out of 100                    43
# 34                      Kolkata    4.7/5  35 out of 100                    79
# 35                  Pondicherry    4.5/5  36 out of 100                    48
# 36                     Pahalgam    4.0/5  37 out of 100                    25
#
#              location                                        description  \
# 0   Jammu and Kashmir  Situated at an altitude of 2730 m above sea le...
# 1              Kerala  Famous for the tea estates, greenery, winding ...
# 2              Sikkim  Incredibly alluring, pleasantly boisterous and...
# 3    Himachal Pradesh  With spectacular valleys, breathtaking views, ...
# 4   Jammu and Kashmir  Famously known as 'Heaven on Earth, Srinagar i...
# 5           Meghalaya  Nestled amidst the pine-clad hills, Shillong, ...
# 6          Tamil Nadu  Nestled amidst Nilgiri hills, Ooty, also known...
# 7         West Bengal  Darjeeling, the former summer capital of India...
# 8                      Ladakh, located in the northernmost region of ...
# 9         Uttarakhand  Located in the foothills of the Himalayas alon...
# 10          Karnataka  Coorg, often called the "Scotland of India," i...
# 11   Himachal Pradesh  Mcleodganj, Himachal Pradesh is one of the mos...
# 12  Jammu and Kashmir  Popularly referred to as the "Paradise on Eart...
# 13  Arunachal Pradesh  Located amidst the majestic Himalayas in Aruna...
# 14         Tamil Nadu  Located in the state of Tamil Nadu, Kodaikanal...
# 15        Uttarakhand  Nainital, a picturesque hill station in the Ku...
# 16   Himachal Pradesh  Shimla is the capital of Himachal Pradesh and ...
# 17        Uttarakhand  Mussoorie, often referred to as the "Queen of ...
# 18   Himachal Pradesh  Often referred to as 'mini-Switzerland of Indi...
# 19             Kerala  Nestled in the Western Ghats of Kerala, Wayana...
# 20      Uttar Pradesh  Located on the banks of River Yamuna in Uttar ...
# 21                     Replete with turquoise blue water beaches and ...
# 22             Kerala  Officially called Alappuzha, Alleppey is known...
# 23                Goa  Lying on the western coast, Goa is India's sma...
# 24             Punjab  Amritsar, colloquially known as Ambarsar, is a...
# 25          Rajasthan  Jaipur, the capital city of Rajasthan, stands ...
# 26          Rajasthan  Udaipur, the "City of Lakes," stands as a jewe...
# 27                Ncr  The capital of India, Delhi is a cosmopolitan ...
# 28        Uttarakhand  Char Dham, which translates to "four abodes," ...
# 29      Uttar Pradesh  World's oldest living city, Varanasi - also kn...
# 30        Maharashtra  Mumbai, the capital city of the Indian state o...
# 31          Rajasthan  Jaisalmer, a mesmerizing destination nestled i...
# 32                     Formerly known as Laccadive Islands, Lakshadwe...
# 33          Rajasthan  Jodhpur, fondly known as the "Blue City" due t...
# 34        West Bengal  Kolkata, India's second biggest city, is a per...
# 35                     Pondicherry, officially known as Puducherry, i...
# 36  Jammu and Kashmir  Situated in the Anantnag district, about 90km ...
#
#                                             known_for  \
# 0     [Gulmarg Gondola, Alpather Lake, Apharwat Peak]
# 1   [Mattupetty Dam, Kolukkumalai Tea Estate, Rose...
# 2           [Nathula Pass, MG Marg, Rumtek Monastery]
# 3   [Solang Valley, Hadimba Devi Temple, Manali Ma...
# 4   [Dal Lake, Indira Gandhi Memorial Tulip Garden...
# 5         [Umiam Lake, Elephant Falls, Shillong Peak]
# 6   [Nilgiri Mountain Railway, Ooty Lake, Emerald ...
# 7   [Darjeeling Himalayan Railway, Darjeeling Peac...
# 8           [Pangong Lake, Khardung La, Nubra Valley]
# 9   [Triveni Ghat, Rafting in Rishikesh, Lakshman ...
# 10            [Abbey Falls, Mandalpatti, Raja's Seat]
# 11  [Naddi View Point, St. John in the Wilderness ...
# 12        [Dal Lake, Gulmarg Gondola, Houseboat Stay]
# 13        [Tawang Monastery, Sela Pass, Madhuri Lake]
# 14  [Green Valley View (Suicide Point), Kodaikanal...
# 15  [Naini Lake, Snow View Point, Mall Road Nainital]
# 16  [Jakhu Temple, Mall Road, Shimla, Rashtrapati ...
# 17     [Mussoorie Mall Road, Lal Tibba, Kempty Falls]
# 18  [Khajjiar lake, Homestay Experience in Khajjia...
# 19  [Edakkal Caves, Banasura Sagar Dam, Chembra Peak]
# 20               [Taj Mahal, Agra Fort, Taj Mahotsav]
# 21  [Radhanagar Beach, Cellular Jail, Scuba Diving...
# 22  [Houseboats in Alleppey, Alleppey Beach, Ambal...
# 23     [Calangute Beach, Baga Beach, Dudhsagar Falls]
# 24  [Golden Temple, Jallianwala Bagh, Partition Mu...
# 25       [Amer Fort, Hawa Mahal, City Palace, Jaipur]
# 26  [City Palace, Udaipur, Lake Pichola, Jagmandir...
# 27                [India Gate, Red Fort, Qutub Minar]
# 28                                                NaN
# 29  [Shri Kashi Vishwanath Temple, Ganga Aarti, Va...
# 30  [Gateway of India, Chhatrapati Shivaji Terminu...
# 31  [Jaisalmer Fort, Desert Safari in Jaisalmer, G...
# 32   [Minicoy Island, Agatti Islands, Kalpeni Island]
# 33  [Mehrangarh Fort, Umaid Bhawan Palace, Mahaman...
# 34  [Victoria Memorial, Fort William Kolkata, Belu...
# 35  [Paradise Beach, Pondicherry, Aurobindo Ashram...
# 36  [Aru Valley, Betaab Valley, River Rafting in P...
#
#                                      best_time
# 0                             October to June
# 1                            September to May
# 2                         Throughout the year
# 3                             October to June
# 4                            April to October
# 5                            September to May
# 6                         Throughout the year
# 7    February to March, September to December
# 8                            April - Mid-July
# 9                         Throughout the year
# 10                           October to March
# 11                            October to June
# 12          September - November; March - May
# 13          March - June; September - October
# 14                           September to May
# 15                        Throughout the year
# 16                            October to June
# 17                          September to June
# 18                        Throughout the year
# 19                        Throughout the year
# 20                           October to March
# 21                             October to Jun
# 22                              June to March
# 23                           October to March
# 24                           October to March
# 25                          November to March
# 26                           October to March
# 27                           October to March
# 28            May - June, September - October
# 29                           October to March
# 30                        October to February
# 31                           October to March
# 32                           September to May
# 33                       November to February
# 34                           October to March
# 35                           October to March
# 36                        Throughout the year

# %%
parent_dir = os.getcwd()
result.to_csv(os.path.join(parent_dir,'tourist_places.csv'),index=False)
print('Stored the Results to CSV file')
# Out:
# Stored the Results to CSV file
